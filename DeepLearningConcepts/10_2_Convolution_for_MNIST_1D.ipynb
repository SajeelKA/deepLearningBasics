# %% [markdown]
# # **Notebook 10.2: Convolution for MNIST-1D**
#
# This notebook investigates a 1D convolutional network for MNIST-1D as in figure 10.7 and 10.8a.
#
# Work through the cells below, running each cell in turn. In various places you will see the words "TO DO". Follow the instructions at these places and make predictions about what is going to happen or write code to complete the functions.
#
# Contact me at udlbookmail@gmail.com if you find any mistakes or have any suggestions.

# %%
# Run this if you're in a Colab to make a local copy of the MNIST 1D repository
# !git clone https://github.com/greydanus/mnist1d
# Out:
# Cloning into 'mnist1d'...
# remote: Enumerating objects: 181, done.
# remote: Counting objects: 100% (53/53), done.
# remote: Compressing objects: 100% (14/14), done.
# remote: Total 181 (delta 41), reused 42 (delta 39), pack-reused 128
# Receiving objects: 100% (181/181), 6.55 MiB | 10.88 MiB/s, done.
# Resolving deltas: 100% (67/67), done.

# %%
import numpy as np
import os
import torch, torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader
from torch.optim.lr_scheduler import StepLR
import matplotlib.pyplot as plt
import mnist1d
import random

# %%
args = mnist1d.data.get_dataset_args()
data = mnist1d.data.get_dataset(args, path='./mnist1d_data.pkl', download=False, regenerate=False)

# The training and test input and outputs are in
# data['x'], data['y'], data['x_test'], and data['y_test']
print("Examples in training set: {}".format(len(data['y'])))
print("Examples in test set: {}".format(len(data['y_test'])))
print("Length of each example: {}".format(data['x'].shape[-1]))
# Out:
# Did or could not load data from ./mnist1d_data.pkl. Rebuilding dataset...
# Examples in training set: 4000
# Examples in test set: 1000
# Length of each example: 40

# %%
# Load in the data
train_data_x = data['x'].transpose()
train_data_y = data['y']
val_data_x = data['x_test'].transpose()
val_data_y = data['y_test']
# Print out sizes
print("Train data: %d examples (columns), each of which has %d dimensions (rows)"%((train_data_x.shape[1],train_data_x.shape[0])))
print("Validation data: %d examples (columns), each of which has %d dimensions (rows)"%((val_data_x.shape[1],val_data_x.shape[0])))
# Out:
# Train data: 4000 examples (columns), each of which has 40 dimensions (rows)
# Validation data: 1000 examples (columns), each of which has 40 dimensions (rows)

# %% [markdown]
# Define the network

# %%
# There are 40 input dimensions and 10 output dimensions for this data
# The inputs correspond to the 40 offsets in the MNIST1D template.
D_i = 40
# The outputs correspond to the 10 digits
D_o = 10


# TODO Create a model with the following layers
# 1. Convolutional layer, (input=length 40 and 1 channel, kernel size 3, stride 2, padding="valid", 15 output channels )
# 2. ReLU
# 3. Convolutional layer, (input=length 19 and 15 channels, kernel size 3, stride 2, padding="valid", 15 output channels )
# 4. ReLU
# 5. Convolutional layer, (input=length 9 and 15 channels, kernel size 3, stride 2, padding="valid", 15 output channels)
# 6. ReLU
# 7. Flatten (converts 4x15) to length 60
# 8. Linear layer (input size = 60, output size = 10)
# References:
# https://pytorch.org/docs/1.13/generated/torch.nn.Conv1d.html?highlight=conv1d#torch.nn.Conv1d
# https://pytorch.org/docs/stable/generated/torch.nn.Flatten.html
# https://pytorch.org/docs/1.13/generated/torch.nn.Linear.html?highlight=linear#torch.nn.Linear

# NOTE THAT THE CONVOLUTIONAL LAYERS NEED TO TAKE THE NUMBER OF INPUT CHANNELS AS A PARAMETER
# AND NOT THE INPUT SIZE.

# Replace the following function:
model = nn.Sequential(
          # nn.Flatten(),
          nn.Conv1d(in_channels=1, out_channels=15, kernel_size=3, stride=2,padding="valid"),
          nn.ReLU(),
          nn.Conv1d(in_channels=15, out_channels=15, kernel_size=3, stride=2,padding="valid"),
          nn.ReLU(),
          nn.Conv1d(in_channels=15, out_channels=15, kernel_size=3, stride=2,padding="valid"),
          nn.ReLU(),
          nn.Flatten(),
          nn.Linear(60, 10)
)

# %%
# He initialization of weights
def weights_init(layer_in):
  if isinstance(layer_in, nn.Linear):
    nn.init.kaiming_uniform_(layer_in.weight)
    layer_in.bias.data.fill_(0.0)

# %%
# choose cross entropy loss function (equation 5.24 in the loss notes)
loss_function = nn.CrossEntropyLoss()
# construct SGD optimizer and initialize learning rate and momentum
optimizer = torch.optim.SGD(model.parameters(), lr = 0.05, momentum=0.9)
# object that decreases learning rate by half every 20 epochs
scheduler = StepLR(optimizer, step_size=20, gamma=0.5)
# create 100 dummy data points and store in data loader class
x_train = torch.tensor(train_data_x.transpose().astype('float32'))
y_train = torch.tensor(train_data_y.astype('long')).long()
x_val= torch.tensor(val_data_x.transpose().astype('float32'))
y_val = torch.tensor(val_data_y.astype('long')).long()

# load the data into a class that creates the batches
data_loader = DataLoader(TensorDataset(x_train,y_train), batch_size=100, shuffle=True, worker_init_fn=np.random.seed(1))

# Initialize model weights
model.apply(weights_init)

# loop over the dataset n_epoch times
n_epoch = 100
# store the loss and the % correct at each epoch
losses_train = np.zeros((n_epoch))
errors_train = np.zeros((n_epoch))
losses_val = np.zeros((n_epoch))
errors_val = np.zeros((n_epoch))

for epoch in range(n_epoch):
  # loop over batches
  for i, data in enumerate(data_loader):
    # retrieve inputs and labels for this batch
    x_batch, y_batch = data
    # zero the parameter gradients
    optimizer.zero_grad()
    # forward pass -- calculate model output
    pred = model(x_batch[:,None,:])
    # compute the loss
    loss = loss_function(pred, y_batch)
    # backward pass
    loss.backward()
    # SGD update
    optimizer.step()

  # Run whole dataset to get statistics -- normally wouldn't do this
  pred_train = model(x_train[:,None,:])
  pred_val = model(x_val[:,None,:])
  _, predicted_train_class = torch.max(pred_train.data, 1)
  _, predicted_val_class = torch.max(pred_val.data, 1)
  errors_train[epoch] = 100 - 100 * (predicted_train_class == y_train).float().sum() / len(y_train)
  errors_val[epoch]= 100 - 100 * (predicted_val_class == y_val).float().sum() / len(y_val)
  losses_train[epoch] = loss_function(pred_train, y_train).item()
  losses_val[epoch]= loss_function(pred_val, y_val).item()
  print(f'Epoch {epoch:5d}, train loss {losses_train[epoch]:.6f}, train error {errors_train[epoch]:3.2f},  val loss {losses_val[epoch]:.6f}, percent error {errors_val[epoch]:3.2f}')

  # tell scheduler to consider updating learning rate
  scheduler.step()

# Plot the results
fig, ax = plt.subplots()
ax.plot(errors_train,'r-',label='train')
ax.plot(errors_val,'b-',label='validation')
ax.set_ylim(0,100); ax.set_xlim(0,n_epoch)
ax.set_xlabel('Epoch'); ax.set_ylabel('Error')
ax.set_title('Part I: Validation Result %3.2f'%(errors_val[-1]))
ax.legend()
plt.show()
# Out:
# Epoch     0, train loss 2.004553, train error 78.70,  val loss 2.005796, percent error 79.70
# Epoch     1, train loss 1.798654, train error 68.20,  val loss 1.832999, percent error 70.40
# Epoch     2, train loss 1.579833, train error 65.15,  val loss 1.598044, percent error 66.60
# Epoch     3, train loss 1.343669, train error 54.45,  val loss 1.352870, percent error 56.40
# Epoch     4, train loss 1.245490, train error 50.12,  val loss 1.275489, percent error 52.80
# Epoch     5, train loss 1.143213, train error 44.35,  val loss 1.172617, percent error 47.90
# Epoch     6, train loss 1.077794, train error 42.28,  val loss 1.123328, percent error 44.80
# Epoch     7, train loss 0.974613, train error 39.25,  val loss 1.023615, percent error 40.20
# Epoch     8, train loss 0.873711, train error 33.18,  val loss 0.922344, percent error 34.60
# Epoch     9, train loss 0.841129, train error 35.10,  val loss 0.922406, percent error 39.90
# Epoch    10, train loss 0.727077, train error 28.70,  val loss 0.797814, percent error 31.50
# Epoch    11, train loss 0.711822, train error 27.88,  val loss 0.794611, percent error 29.80
# Epoch    12, train loss 0.632392, train error 24.40,  val loss 0.704412, percent error 26.50
# Epoch    13, train loss 0.523272, train error 20.45,  val loss 0.616230, percent error 24.50
# Epoch    14, train loss 0.583532, train error 22.95,  val loss 0.724037, percent error 28.20
# Epoch    15, train loss 0.552864, train error 21.70,  val loss 0.670344, percent error 24.60
# Epoch    16, train loss 0.563711, train error 22.20,  val loss 0.662946, percent error 25.90
# Epoch    17, train loss 0.438171, train error 16.95,  val loss 0.566736, percent error 20.70
# Epoch    18, train loss 0.427297, train error 15.97,  val loss 0.505491, percent error 18.50
# Epoch    19, train loss 0.280764, train error 10.25,  val loss 0.406081, percent error 15.00
# Epoch    20, train loss 0.278411, train error 10.25,  val loss 0.390607, percent error 14.70
# Epoch    21, train loss 0.234933, train error 7.68,  val loss 0.356331, percent error 13.50
# Epoch    22, train loss 0.225087, train error 7.72,  val loss 0.366699, percent error 14.40
# Epoch    23, train loss 0.209007, train error 7.25,  val loss 0.353600, percent error 12.10
# Epoch    24, train loss 0.189133, train error 5.97,  val loss 0.342998, percent error 12.30
# Epoch    25, train loss 0.182674, train error 6.30,  val loss 0.333205, percent error 11.60
# Epoch    26, train loss 0.169522, train error 5.40,  val loss 0.336091, percent error 11.60
# Epoch    27, train loss 0.182891, train error 5.75,  val loss 0.352965, percent error 11.70
# Epoch    28, train loss 0.180250, train error 6.32,  val loss 0.353321, percent error 11.60
# Epoch    29, train loss 0.146040, train error 4.68,  val loss 0.328856, percent error 11.30
# Epoch    30, train loss 0.169415, train error 6.07,  val loss 0.342820, percent error 10.90
# Epoch    31, train loss 0.139374, train error 4.40,  val loss 0.335032, percent error 10.50
# Epoch    32, train loss 0.138406, train error 4.82,  val loss 0.301405, percent error 9.80
# Epoch    33, train loss 0.150294, train error 5.30,  val loss 0.334294, percent error 10.80
# Epoch    34, train loss 0.133449, train error 4.32,  val loss 0.322827, percent error 10.10
# Epoch    35, train loss 0.120823, train error 4.22,  val loss 0.324538, percent error 10.20
# Epoch    36, train loss 0.116755, train error 3.88,  val loss 0.312944, percent error 10.20
# Epoch    37, train loss 0.120341, train error 4.10,  val loss 0.334443, percent error 10.50
# Epoch    38, train loss 0.115082, train error 3.97,  val loss 0.318620, percent error 10.50
# Epoch    39, train loss 0.121220, train error 4.03,  val loss 0.317254, percent error 10.10
# Epoch    40, train loss 0.081531, train error 2.45,  val loss 0.299843, percent error 9.00
# Epoch    41, train loss 0.080353, train error 2.45,  val loss 0.314557, percent error 9.40
# Epoch    42, train loss 0.081451, train error 2.43,  val loss 0.314304, percent error 9.30
# Epoch    43, train loss 0.079064, train error 2.25,  val loss 0.319988, percent error 8.90
# Epoch    44, train loss 0.074331, train error 2.22,  val loss 0.322250, percent error 8.80
# Epoch    45, train loss 0.073293, train error 2.07,  val loss 0.313934, percent error 9.60
# Epoch    46, train loss 0.074715, train error 2.18,  val loss 0.330165, percent error 9.30
# Epoch    47, train loss 0.073862, train error 2.18,  val loss 0.318781, percent error 8.90
# Epoch    48, train loss 0.072052, train error 2.20,  val loss 0.338897, percent error 9.60
# Epoch    49, train loss 0.071591, train error 2.18,  val loss 0.344750, percent error 10.00
# Epoch    50, train loss 0.064915, train error 1.85,  val loss 0.321740, percent error 9.20
# Epoch    51, train loss 0.069646, train error 1.97,  val loss 0.337221, percent error 8.40
# Epoch    52, train loss 0.068391, train error 2.03,  val loss 0.352544, percent error 9.00
# Epoch    53, train loss 0.060756, train error 1.72,  val loss 0.343581, percent error 10.20
# Epoch    54, train loss 0.058304, train error 1.57,  val loss 0.343460, percent error 9.50
# Epoch    55, train loss 0.059069, train error 1.53,  val loss 0.335955, percent error 9.00
# Epoch    56, train loss 0.054508, train error 1.55,  val loss 0.347106, percent error 9.50
# Epoch    57, train loss 0.054951, train error 1.45,  val loss 0.351237, percent error 9.90
# Epoch    58, train loss 0.064764, train error 1.93,  val loss 0.362909, percent error 9.80
# Epoch    59, train loss 0.054407, train error 1.53,  val loss 0.350141, percent error 9.30
# Epoch    60, train loss 0.048386, train error 1.28,  val loss 0.351598, percent error 9.10
# Epoch    61, train loss 0.049656, train error 1.35,  val loss 0.350604, percent error 9.70
# Epoch    62, train loss 0.047783, train error 1.10,  val loss 0.347808, percent error 8.80
# Epoch    63, train loss 0.046985, train error 0.93,  val loss 0.356987, percent error 9.20
# Epoch    64, train loss 0.046644, train error 1.10,  val loss 0.357314, percent error 9.80
# Epoch    65, train loss 0.043940, train error 0.95,  val loss 0.353528, percent error 9.30
# Epoch    66, train loss 0.045266, train error 1.03,  val loss 0.362109, percent error 9.10
# Epoch    67, train loss 0.044936, train error 1.00,  val loss 0.356493, percent error 9.00
# Epoch    68, train loss 0.042522, train error 0.88,  val loss 0.361144, percent error 9.00
# Epoch    69, train loss 0.042613, train error 0.80,  val loss 0.360933, percent error 9.00
# Epoch    70, train loss 0.042205, train error 0.82,  val loss 0.364878, percent error 9.40
# Epoch    71, train loss 0.042369, train error 0.88,  val loss 0.367485, percent error 9.40
# Epoch    72, train loss 0.044423, train error 1.00,  val loss 0.367998, percent error 9.60
# Epoch    73, train loss 0.040246, train error 0.88,  val loss 0.363865, percent error 8.90
# Epoch    74, train loss 0.039737, train error 0.75,  val loss 0.368767, percent error 9.00
# Epoch    75, train loss 0.039731, train error 0.80,  val loss 0.371831, percent error 9.10
# Epoch    76, train loss 0.038883, train error 0.78,  val loss 0.369261, percent error 8.90
# Epoch    77, train loss 0.038211, train error 0.68,  val loss 0.371179, percent error 9.00
# Epoch    78, train loss 0.037897, train error 0.60,  val loss 0.371577, percent error 9.40
# Epoch    79, train loss 0.040107, train error 0.88,  val loss 0.371015, percent error 9.50
# Epoch    80, train loss 0.036300, train error 0.60,  val loss 0.370608, percent error 8.90
# Epoch    81, train loss 0.036815, train error 0.60,  val loss 0.373415, percent error 8.70
# Epoch    82, train loss 0.035925, train error 0.57,  val loss 0.374405, percent error 9.00
# Epoch    83, train loss 0.036116, train error 0.53,  val loss 0.377226, percent error 8.60
# Epoch    84, train loss 0.035430, train error 0.55,  val loss 0.373563, percent error 8.90
# Epoch    85, train loss 0.035452, train error 0.53,  val loss 0.373563, percent error 8.70
# Epoch    86, train loss 0.034837, train error 0.53,  val loss 0.374269, percent error 9.10
# Epoch    87, train loss 0.035021, train error 0.50,  val loss 0.376361, percent error 8.90
# Epoch    88, train loss 0.034539, train error 0.53,  val loss 0.376844, percent error 8.90
# Epoch    89, train loss 0.034438, train error 0.50,  val loss 0.378288, percent error 9.10
# Epoch    90, train loss 0.034141, train error 0.57,  val loss 0.376245, percent error 8.90
# Epoch    91, train loss 0.034289, train error 0.47,  val loss 0.379036, percent error 9.00
# Epoch    92, train loss 0.033777, train error 0.53,  val loss 0.377955, percent error 9.00
# Epoch    93, train loss 0.033793, train error 0.53,  val loss 0.381388, percent error 9.20
# Epoch    94, train loss 0.033439, train error 0.53,  val loss 0.381310, percent error 9.10
# Epoch    95, train loss 0.033054, train error 0.45,  val loss 0.380381, percent error 9.00
# Epoch    96, train loss 0.033362, train error 0.50,  val loss 0.381425, percent error 8.80
# Epoch    97, train loss 0.032649, train error 0.47,  val loss 0.381163, percent error 8.90
# Epoch    98, train loss 0.033264, train error 0.50,  val loss 0.384718, percent error 9.00
# Epoch    99, train loss 0.032566, train error 0.45,  val loss 0.385269, percent error 9.10

# %%
# plt.imshow(x_train)
