# %% [markdown]
# # **Notebook 8.1: MNIST_1D_Performance**
#
# This notebook runs a simple neural network on the MNIST1D dataset as in figure 8.2a. It uses code from https://github.com/greydanus/mnist1d to generate the data.
#
# Work through the cells below, running each cell in turn. In various places you will see the words "TO DO". Follow the instructions at these places and make predictions about what is going to happen or write code to complete the functions.
#
# Contact me at udlbookmail@gmail.com if you find any mistakes or have any suggestions.

# %%
# Run this if you're in a Colab to make a local copy of the MNIST 1D repository
# !git clone https://github.com/greydanus/mnist1d
# Out:
# Cloning into 'mnist1d'...
# remote: Enumerating objects: 155, done.
# remote: Counting objects: 100% (155/155), done.
# remote: Compressing objects: 100% (129/129), done.
# remote: Total 155 (delta 52), reused 124 (delta 26), pack-reused 0
# Receiving objects: 100% (155/155), 6.48 MiB | 18.73 MiB/s, done.
# Resolving deltas: 100% (52/52), done.

# %%
import torch, torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader
from torch.optim.lr_scheduler import StepLR
import numpy as np
import matplotlib.pyplot as plt
import mnist1d

# %% [markdown]
# Let's generate a training and test dataset using the MNIST1D code.  The dataset gets saved as a .pkl file so it doesn't have to be regenerated each time.

# %%
args = mnist1d.data.get_dataset_args()
data = mnist1d.data.get_dataset(args, path='./sample_data/mnist1d_data.pkl', download=False, regenerate=False)

# The training and test input and outputs are in
# data['x'], data['y'], data['x_test'], and data['y_test']
print("Examples in training set: {}".format(len(data['y'])))
print("Examples in test set: {}".format(len(data['y_test'])))
print("Length of each example: {}".format(data['x'].shape[-1]))
# Out:
# Did or could not load data from ./sample_data/mnist1d_data.pkl. Rebuilding dataset...
# Examples in training set: 4000
# Examples in test set: 1000
# Length of each example: 40

# %%
D_i = 40    # Input dimensions
D_k = 100   # Hidden dimensions
D_o = 10    # Output dimensions
# TO DO:
# Define a model with two hidden layers of size 100
# And ReLU activations between them
# Replace this line (see Figure 7.8 of book for help):
model = torch.nn.Sequential(torch.nn.Linear(D_i, D_o));


def weights_init(layer_in):
  # TO DO:
  # Initialize the parameters with He initialization
  # Replace this line (see figure 7.8 of book for help)
  if isinstance(layer_in, nn.Linear):
    nn.init.kaiming_uniform_(layer_in.weight)
    layer_in.bias.data.fill_(0.0)
  print("Initializing layer")


# Call the function you just defined
model.apply(weights_init)
# Out:
# Initializing layer
# Initializing layer
# Sequential(
#   (0): Linear(in_features=40, out_features=10, bias=True)
# )

# %%
# choose cross entropy loss function (equation 5.24)
loss_function = torch.nn.CrossEntropyLoss()
# construct SGD optimizer and initialize learning rate and momentum
optimizer = torch.optim.SGD(model.parameters(), lr = 0.05, momentum=0.1)
# object that decreases learning rate by half every 10 epochs
scheduler = StepLR(optimizer, step_size=20, gamma=0.5)
# create 100 dummy data points and store in data loader class
x_train = torch.tensor(data['x'].astype('float32'))
y_train = torch.tensor(data['y'].transpose().astype('long'))
x_test= torch.tensor(data['x_test'].astype('float32'))
y_test = torch.tensor(data['y_test'].astype('long'))

# load the data into a class that creates the batches
data_loader = DataLoader(TensorDataset(x_train,y_train), batch_size=100, shuffle=True, worker_init_fn=np.random.seed(1))

# Initialize model weights
model.apply(weights_init)

# loop over the dataset n_epoch times
n_epoch = 50
# store the loss and the % correct at each epoch
losses_train = np.zeros((n_epoch))
errors_train = np.zeros((n_epoch))
losses_test = np.zeros((n_epoch))
errors_test = np.zeros((n_epoch))

for epoch in range(n_epoch):
  # loop over batches
  for i, batch in enumerate(data_loader):
    # retrieve inputs and labels for this batch
    x_batch, y_batch = batch
    # zero the parameter gradients
    optimizer.zero_grad()
    # forward pass -- calculate model output
    pred = model(x_batch)
    # compute the loss
    loss = loss_function(pred, y_batch)
    # backward pass
    loss.backward()
    # SGD update
    optimizer.step()

  # Run whole dataset to get statistics -- normally wouldn't do this
  pred_train = model(x_train)
  pred_test = model(x_test)
  _, predicted_train_class = torch.max(pred_train.data, 1)
  _, predicted_test_class = torch.max(pred_test.data, 1)
  errors_train[epoch] = 100 - 100 * (predicted_train_class == y_train).float().sum() / len(y_train)
  errors_test[epoch]= 100 - 100 * (predicted_test_class == y_test).float().sum() / len(y_test)
  losses_train[epoch] = loss_function(pred_train, y_train).item()
  losses_test[epoch]= loss_function(pred_test, y_test).item()
  print(f'Epoch {epoch:5d}, train loss {losses_train[epoch]:.6f}, train error {errors_train[epoch]:3.2f},  test loss {losses_test[epoch]:.6f}, test error {errors_test[epoch]:3.2f}')

  # tell scheduler to consider updating learning rate
  scheduler.step()
# Out:
# Initializing layer
# Initializing layer
# Epoch     0, train loss 2.188605, train error 78.05,  test loss 2.190380, test error 78.30
# Epoch     1, train loss 2.002764, train error 74.55,  test loss 2.007494, test error 76.40
# Epoch     2, train loss 1.918930, train error 72.65,  test loss 1.926256, test error 74.00
# Epoch     3, train loss 1.868797, train error 71.30,  test loss 1.879233, test error 73.10
# Epoch     4, train loss 1.833421, train error 70.25,  test loss 1.845845, test error 72.30
# Epoch     5, train loss 1.806901, train error 70.15,  test loss 1.822922, test error 71.50
# Epoch     6, train loss 1.785817, train error 69.43,  test loss 1.804610, test error 71.20
# Epoch     7, train loss 1.768661, train error 68.90,  test loss 1.790417, test error 71.20
# Epoch     8, train loss 1.754143, train error 68.62,  test loss 1.778352, test error 71.50
# Epoch     9, train loss 1.741805, train error 68.05,  test loss 1.767381, test error 71.50
# Epoch    10, train loss 1.731107, train error 67.95,  test loss 1.756711, test error 70.70
# Epoch    11, train loss 1.721662, train error 67.78,  test loss 1.751832, test error 70.60
# Epoch    12, train loss 1.713476, train error 67.53,  test loss 1.744543, test error 70.50
# Epoch    13, train loss 1.706054, train error 66.85,  test loss 1.737678, test error 70.80
# Epoch    14, train loss 1.699698, train error 66.43,  test loss 1.734408, test error 70.70
# Epoch    15, train loss 1.693509, train error 66.28,  test loss 1.726263, test error 70.80
# Epoch    16, train loss 1.688433, train error 66.15,  test loss 1.722883, test error 70.90
# Epoch    17, train loss 1.683388, train error 65.90,  test loss 1.718017, test error 70.90
# Epoch    18, train loss 1.678565, train error 65.55,  test loss 1.715027, test error 71.00
# Epoch    19, train loss 1.674460, train error 65.30,  test loss 1.712987, test error 70.90
# Epoch    20, train loss 1.672420, train error 65.15,  test loss 1.711050, test error 71.00
# Epoch    21, train loss 1.670458, train error 64.88,  test loss 1.708797, test error 70.80
# Epoch    22, train loss 1.668597, train error 64.90,  test loss 1.707273, test error 71.10
# Epoch    23, train loss 1.666880, train error 64.72,  test loss 1.705514, test error 71.10
# Epoch    24, train loss 1.665158, train error 64.75,  test loss 1.704181, test error 71.10
# Epoch    25, train loss 1.663542, train error 64.62,  test loss 1.702540, test error 70.40
# Epoch    26, train loss 1.661948, train error 64.78,  test loss 1.701084, test error 70.30
# Epoch    27, train loss 1.660480, train error 64.43,  test loss 1.699741, test error 70.40
# Epoch    28, train loss 1.659024, train error 64.57,  test loss 1.698405, test error 70.50
# Epoch    29, train loss 1.657563, train error 64.90,  test loss 1.697960, test error 70.40
# Epoch    30, train loss 1.656203, train error 64.55,  test loss 1.696626, test error 70.30
# Epoch    31, train loss 1.654863, train error 64.55,  test loss 1.695633, test error 70.40
# Epoch    32, train loss 1.653574, train error 64.47,  test loss 1.694527, test error 70.50
# Epoch    33, train loss 1.652313, train error 64.57,  test loss 1.693857, test error 70.50
# Epoch    34, train loss 1.651101, train error 64.47,  test loss 1.692800, test error 70.30
# Epoch    35, train loss 1.649955, train error 64.50,  test loss 1.691502, test error 69.60
# Epoch    36, train loss 1.648788, train error 64.28,  test loss 1.690470, test error 69.90
# Epoch    37, train loss 1.647743, train error 64.38,  test loss 1.689063, test error 69.90
# Epoch    38, train loss 1.646648, train error 64.32,  test loss 1.688209, test error 69.70
# Epoch    39, train loss 1.645605, train error 64.07,  test loss 1.687666, test error 69.30
# Epoch    40, train loss 1.645067, train error 64.12,  test loss 1.687302, test error 69.40
# Epoch    41, train loss 1.644535, train error 64.28,  test loss 1.686997, test error 69.50
# Epoch    42, train loss 1.644032, train error 64.28,  test loss 1.686485, test error 69.60
# Epoch    43, train loss 1.643544, train error 64.20,  test loss 1.686261, test error 69.60
# Epoch    44, train loss 1.643049, train error 64.22,  test loss 1.685974, test error 69.90
# Epoch    45, train loss 1.642581, train error 64.28,  test loss 1.685405, test error 69.50
# Epoch    46, train loss 1.642104, train error 64.22,  test loss 1.685127, test error 69.50
# Epoch    47, train loss 1.641638, train error 64.30,  test loss 1.684795, test error 69.50
# Epoch    48, train loss 1.641178, train error 64.25,  test loss 1.684538, test error 69.30
# Epoch    49, train loss 1.640725, train error 64.38,  test loss 1.684196, test error 69.40

# %%
# Plot the results
fig, ax = plt.subplots()
ax.plot(errors_train,'r-',label='train')
ax.plot(errors_test,'b-',label='test')
ax.set_ylim(0,100); ax.set_xlim(0,n_epoch)
ax.set_xlabel('Epoch'); ax.set_ylabel('Error')
ax.set_title('TrainError %3.2f, Test Error %3.2f'%(errors_train[-1],errors_test[-1]))
ax.legend()
plt.show()

# Plot the results
fig, ax = plt.subplots()
ax.plot(losses_train,'r-',label='train')
ax.plot(losses_test,'b-',label='test')
ax.set_xlim(0,n_epoch)
ax.set_xlabel('Epoch'); ax.set_ylabel('Loss')
ax.set_title('Train loss %3.2f, Test loss %3.2f'%(losses_train[-1],losses_test[-1]))
ax.legend()
plt.show()

# %% [markdown]
# **TO DO**
#
# Play with the model -- try changing the number of layers, hidden units, learning rate, batch size, momentum or anything else you like.  See if you can improve the test results.
#
# Is it a good idea to optimize the hyperparameters in this way?  Will the final result be a good estimate of the true test performance?
