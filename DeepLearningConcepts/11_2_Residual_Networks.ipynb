# %% [markdown]
# # **Notebook 11.2: Residual Networks**
#
# This notebook adapts the networks for MNIST1D to use residual connections.
#
# Work through the cells below, running each cell in turn. In various places you will see the words "TO DO". Follow the instructions at these places and make predictions about what is going to happen or write code to complete the functions.
#
# Contact me at udlbookmail@gmail.com if you find any mistakes or have any suggestions.

# %%
# Run this if you're in a Colab to make a local copy of the MNIST 1D repository
# !git clone https://github.com/greydanus/mnist1d
# Out:
# fatal: destination path 'mnist1d' already exists and is not an empty directory.

# %%
import numpy as np
import os
import torch, torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader
from torch.optim.lr_scheduler import StepLR
import matplotlib.pyplot as plt
import mnist1d
import random

# %%
args = mnist1d.data.get_dataset_args()
data = mnist1d.data.get_dataset(args, path='./mnist1d_data.pkl', download=False, regenerate=False)

# The training and test input and outputs are in
# data['x'], data['y'], data['x_test'], and data['y_test']
print("Examples in training set: {}".format(len(data['y'])))
print("Examples in test set: {}".format(len(data['y_test'])))
print("Length of each example: {}".format(data['x'].shape[-1]))
# Out:
# Successfully loaded data from ./mnist1d_data.pkl
# Examples in training set: 4000
# Examples in test set: 1000
# Length of each example: 40

# %%
# Load in the data
train_data_x = data['x'].transpose()
train_data_y = data['y']
val_data_x = data['x_test'].transpose()
val_data_y = data['y_test']
# Print out sizes
print("Train data: %d examples (columns), each of which has %d dimensions (rows)"%((train_data_x.shape[1],train_data_x.shape[0])))
print("Validation data: %d examples (columns), each of which has %d dimensions (rows)"%((val_data_x.shape[1],val_data_x.shape[0])))
# Out:
# Train data: 4000 examples (columns), each of which has 40 dimensions (rows)
# Validation data: 1000 examples (columns), each of which has 40 dimensions (rows)

# %% [markdown]
# Define the network

# %%
# There are 40 input dimensions and 10 output dimensions for this data
# The inputs correspond to the 40 offsets in the MNIST1D template.
D_i = 40
# The outputs correspond to the 10 digits
D_o = 10


# We will adapt this model to have residual connections around the linear layers
# This is the same model we used in practical 8.1, but we can't use the sequential
# class for residual networks (which aren't strictly sequential).  Hence, I've rewritten
# it as a model that inherits from a base class

class ResidualNetwork(torch.nn.Module):
  def __init__(self, input_size, output_size, hidden_size=100):
    super(ResidualNetwork, self).__init__()
    self.linear1 = nn.Linear(input_size, hidden_size)
    self.linear2 = nn.Linear(hidden_size, hidden_size)
    self.linear3 = nn.Linear(hidden_size, hidden_size)
    self.linear4 = nn.Linear(hidden_size, output_size)
    print("Initialized MLPBase model with {} parameters".format(self.count_params()))

  def count_params(self):
    return sum([p.view(-1).shape[0] for p in self.parameters()])

# TODO -- Add residual connections to this model
# The order of operations within each block should similar to figure 11.5b
# ie., linear1 first, ReLU+linear2 in first residual block, ReLU+linear3 in second residual block), linear4 at end
# Replace this function
  def forward(self, x):
    h1 = self.linear1(x)
    h2 = h1 + self.linear2(h1.relu())
    h3 = h2 + self.linear3(h2.relu())

    return self.linear4(h3)

# %%
# He initialization of weights
def weights_init(layer_in):
  if isinstance(layer_in, nn.Linear):
    nn.init.kaiming_uniform_(layer_in.weight)
    layer_in.bias.data.fill_(0.0)

# %%
#Define the model
model = ResidualNetwork(40, 10)

# choose cross entropy loss function (equation 5.24 in the loss notes)
loss_function = nn.CrossEntropyLoss()
# construct SGD optimizer and initialize learning rate and momentum
optimizer = torch.optim.SGD(model.parameters(), lr = 0.05, momentum=0.9)
# object that decreases learning rate by half every 20 epochs
scheduler = StepLR(optimizer, step_size=20, gamma=0.5)
# convert data to torch tensors
x_train = torch.tensor(train_data_x.transpose().astype('float32'))
y_train = torch.tensor(train_data_y.astype('long'))
x_val= torch.tensor(val_data_x.transpose().astype('float32'))
y_val = torch.tensor(val_data_y.astype('long'))

# load the data into a class that creates the batches
data_loader = DataLoader(TensorDataset(x_train,y_train), batch_size=100, shuffle=True, worker_init_fn=np.random.seed(1))

# Initialize model weights
model.apply(weights_init)

# loop over the dataset n_epoch times
n_epoch = 100
# store the loss and the % correct at each epoch
losses_train = np.zeros((n_epoch))
errors_train = np.zeros((n_epoch))
losses_val = np.zeros((n_epoch))
errors_val = np.zeros((n_epoch))

for epoch in range(n_epoch):
  # loop over batches
  for i, data in enumerate(data_loader):
    # retrieve inputs and labels for this batch
    x_batch, y_batch = data
    # zero the parameter gradients
    optimizer.zero_grad()
    # forward pass -- calculate model output
    pred = model(x_batch)
    # compute the loss
    loss = loss_function(pred, y_batch)
    # backward pass
    loss.backward()
    # SGD update
    optimizer.step()

  # Run whole dataset to get statistics -- normally wouldn't do this
  pred_train = model(x_train)
  pred_val = model(x_val)
  _, predicted_train_class = torch.max(pred_train.data, 1)
  _, predicted_val_class = torch.max(pred_val.data, 1)
  errors_train[epoch] = 100 - 100 * (predicted_train_class == y_train).float().sum() / len(y_train)
  errors_val[epoch]= 100 - 100 * (predicted_val_class == y_val).float().sum() / len(y_val)
  losses_train[epoch] = loss_function(pred_train, y_train).item()
  losses_val[epoch]= loss_function(pred_val, y_val).item()
  print(f'Epoch {epoch:5d}, train loss {losses_train[epoch]:.6f}, train error {errors_train[epoch]:3.2f},  val loss {losses_val[epoch]:.6f}, percent error {errors_val[epoch]:3.2f}')

  # tell scheduler to consider updating learning rate
  scheduler.step()
# Out:
# Initialized MLPBase model with 25310 parameters
# Epoch     0, train loss 1.597799, train error 60.80,  val loss 1.659020, percent error 63.30
# Epoch     1, train loss 1.166632, train error 44.80,  val loss 1.329750, percent error 52.50
# Epoch     2, train loss 1.003976, train error 37.08,  val loss 1.163439, percent error 44.10
# Epoch     3, train loss 0.913610, train error 35.35,  val loss 1.203630, percent error 45.90
# Epoch     4, train loss 0.814775, train error 30.80,  val loss 1.192256, percent error 43.70
# Epoch     5, train loss 0.703659, train error 26.78,  val loss 1.102233, percent error 41.00
# Epoch     6, train loss 0.643317, train error 24.10,  val loss 1.132338, percent error 41.10
# Epoch     7, train loss 0.710590, train error 27.25,  val loss 1.279276, percent error 44.20
# Epoch     8, train loss 0.623374, train error 22.82,  val loss 1.253541, percent error 39.70
# Epoch     9, train loss 0.460574, train error 17.47,  val loss 1.176800, percent error 39.70
# Epoch    10, train loss 0.495465, train error 18.35,  val loss 1.299552, percent error 38.70
# Epoch    11, train loss 0.536919, train error 19.32,  val loss 1.406671, percent error 39.90
# Epoch    12, train loss 0.391092, train error 14.20,  val loss 1.268573, percent error 37.80
# Epoch    13, train loss 0.360757, train error 13.70,  val loss 1.269583, percent error 35.70
# Epoch    14, train loss 0.352875, train error 13.68,  val loss 1.352950, percent error 35.80
# Epoch    15, train loss 0.330455, train error 12.00,  val loss 1.437696, percent error 37.00
# Epoch    16, train loss 0.312263, train error 11.47,  val loss 1.445562, percent error 35.00
# Epoch    17, train loss 0.463422, train error 15.88,  val loss 1.771132, percent error 37.80
# Epoch    18, train loss 0.332557, train error 12.07,  val loss 1.531382, percent error 34.20
# Epoch    19, train loss 0.294694, train error 10.50,  val loss 1.438702, percent error 33.80
# Epoch    20, train loss 0.089531, train error 2.80,  val loss 1.331010, percent error 31.30
# Epoch    21, train loss 0.049388, train error 0.93,  val loss 1.299918, percent error 31.20
# Epoch    22, train loss 0.025215, train error 0.12,  val loss 1.270113, percent error 29.50
# Epoch    23, train loss 0.019581, train error 0.05,  val loss 1.305258, percent error 29.80
# Epoch    24, train loss 0.013928, train error 0.00,  val loss 1.334076, percent error 29.90
# Epoch    25, train loss 0.011265, train error 0.00,  val loss 1.344886, percent error 29.20
# Epoch    26, train loss 0.009646, train error 0.00,  val loss 1.382209, percent error 29.60
# Epoch    27, train loss 0.008305, train error 0.00,  val loss 1.407735, percent error 29.30
# Epoch    28, train loss 0.007343, train error 0.00,  val loss 1.425007, percent error 29.30
# Epoch    29, train loss 0.006653, train error 0.00,  val loss 1.445132, percent error 29.30
# Epoch    30, train loss 0.006031, train error 0.00,  val loss 1.462943, percent error 29.30
# Epoch    31, train loss 0.005528, train error 0.00,  val loss 1.476007, percent error 29.10
# Epoch    32, train loss 0.005115, train error 0.00,  val loss 1.494766, percent error 29.20
# Epoch    33, train loss 0.004742, train error 0.00,  val loss 1.507770, percent error 29.80
# Epoch    34, train loss 0.004422, train error 0.00,  val loss 1.524070, percent error 29.80
# Epoch    35, train loss 0.004146, train error 0.00,  val loss 1.535967, percent error 29.30
# Epoch    36, train loss 0.003899, train error 0.00,  val loss 1.549078, percent error 29.60
# Epoch    37, train loss 0.003691, train error 0.00,  val loss 1.559510, percent error 29.80
# Epoch    38, train loss 0.003485, train error 0.00,  val loss 1.573356, percent error 29.40
# Epoch    39, train loss 0.003306, train error 0.00,  val loss 1.581908, percent error 29.60
# Epoch    40, train loss 0.003218, train error 0.00,  val loss 1.587979, percent error 29.50
# Epoch    41, train loss 0.003141, train error 0.00,  val loss 1.592160, percent error 29.50
# Epoch    42, train loss 0.003067, train error 0.00,  val loss 1.597729, percent error 29.60
# Epoch    43, train loss 0.002999, train error 0.00,  val loss 1.603583, percent error 29.40
# Epoch    44, train loss 0.002932, train error 0.00,  val loss 1.605849, percent error 29.60
# Epoch    45, train loss 0.002868, train error 0.00,  val loss 1.611414, percent error 29.60
# Epoch    46, train loss 0.002806, train error 0.00,  val loss 1.616383, percent error 29.60
# Epoch    47, train loss 0.002748, train error 0.00,  val loss 1.621893, percent error 29.70
# Epoch    48, train loss 0.002690, train error 0.00,  val loss 1.624951, percent error 29.60
# Epoch    49, train loss 0.002637, train error 0.00,  val loss 1.629952, percent error 29.60
# Epoch    50, train loss 0.002583, train error 0.00,  val loss 1.634481, percent error 29.60
# Epoch    51, train loss 0.002533, train error 0.00,  val loss 1.638291, percent error 29.70
# Epoch    52, train loss 0.002486, train error 0.00,  val loss 1.642285, percent error 29.60
# Epoch    53, train loss 0.002437, train error 0.00,  val loss 1.647047, percent error 29.70
# Epoch    54, train loss 0.002392, train error 0.00,  val loss 1.649988, percent error 29.70
# Epoch    55, train loss 0.002348, train error 0.00,  val loss 1.654479, percent error 29.60
# Epoch    56, train loss 0.002305, train error 0.00,  val loss 1.657587, percent error 29.70
# Epoch    57, train loss 0.002264, train error 0.00,  val loss 1.662915, percent error 29.80
# Epoch    58, train loss 0.002225, train error 0.00,  val loss 1.666211, percent error 29.80
# Epoch    59, train loss 0.002187, train error 0.00,  val loss 1.669378, percent error 29.80
# Epoch    60, train loss 0.002168, train error 0.00,  val loss 1.671175, percent error 29.80
# Epoch    61, train loss 0.002149, train error 0.00,  val loss 1.673001, percent error 29.80
# Epoch    62, train loss 0.002131, train error 0.00,  val loss 1.675118, percent error 29.80
# Epoch    63, train loss 0.002114, train error 0.00,  val loss 1.676810, percent error 29.80
# Epoch    64, train loss 0.002097, train error 0.00,  val loss 1.678309, percent error 29.60
# Epoch    65, train loss 0.002079, train error 0.00,  val loss 1.680243, percent error 29.70
# Epoch    66, train loss 0.002062, train error 0.00,  val loss 1.681832, percent error 29.60
# Epoch    67, train loss 0.002046, train error 0.00,  val loss 1.683580, percent error 29.60
# Epoch    68, train loss 0.002029, train error 0.00,  val loss 1.685096, percent error 29.50
# Epoch    69, train loss 0.002013, train error 0.00,  val loss 1.686940, percent error 29.60
# Epoch    70, train loss 0.001998, train error 0.00,  val loss 1.688540, percent error 29.70
# Epoch    71, train loss 0.001982, train error 0.00,  val loss 1.690085, percent error 29.70
# Epoch    72, train loss 0.001967, train error 0.00,  val loss 1.692178, percent error 29.60
# Epoch    73, train loss 0.001951, train error 0.00,  val loss 1.693657, percent error 29.60
# Epoch    74, train loss 0.001936, train error 0.00,  val loss 1.695718, percent error 29.70
# Epoch    75, train loss 0.001922, train error 0.00,  val loss 1.696805, percent error 29.60
# Epoch    76, train loss 0.001907, train error 0.00,  val loss 1.698361, percent error 29.60
# Epoch    77, train loss 0.001893, train error 0.00,  val loss 1.700168, percent error 29.60
# Epoch    78, train loss 0.001879, train error 0.00,  val loss 1.701531, percent error 29.50
# Epoch    79, train loss 0.001865, train error 0.00,  val loss 1.703163, percent error 29.60
# Epoch    80, train loss 0.001858, train error 0.00,  val loss 1.703863, percent error 29.60
# Epoch    81, train loss 0.001851, train error 0.00,  val loss 1.704877, percent error 29.60
# Epoch    82, train loss 0.001844, train error 0.00,  val loss 1.705514, percent error 29.60
# Epoch    83, train loss 0.001838, train error 0.00,  val loss 1.706448, percent error 29.60
# Epoch    84, train loss 0.001831, train error 0.00,  val loss 1.707060, percent error 29.60
# Epoch    85, train loss 0.001825, train error 0.00,  val loss 1.707955, percent error 29.50
# Epoch    86, train loss 0.001818, train error 0.00,  val loss 1.708764, percent error 29.50
# Epoch    87, train loss 0.001811, train error 0.00,  val loss 1.709489, percent error 29.70
# Epoch    88, train loss 0.001805, train error 0.00,  val loss 1.710106, percent error 29.50
# Epoch    89, train loss 0.001798, train error 0.00,  val loss 1.710925, percent error 29.60
# Epoch    90, train loss 0.001792, train error 0.00,  val loss 1.711796, percent error 29.50
# Epoch    91, train loss 0.001786, train error 0.00,  val loss 1.712646, percent error 29.50
# Epoch    92, train loss 0.001779, train error 0.00,  val loss 1.713172, percent error 29.60
# Epoch    93, train loss 0.001773, train error 0.00,  val loss 1.713938, percent error 29.50
# Epoch    94, train loss 0.001767, train error 0.00,  val loss 1.714760, percent error 29.60
# Epoch    95, train loss 0.001761, train error 0.00,  val loss 1.715559, percent error 29.60
# Epoch    96, train loss 0.001754, train error 0.00,  val loss 1.716338, percent error 29.60
# Epoch    97, train loss 0.001748, train error 0.00,  val loss 1.716943, percent error 29.50
# Epoch    98, train loss 0.001742, train error 0.00,  val loss 1.717649, percent error 29.50
# Epoch    99, train loss 0.001736, train error 0.00,  val loss 1.718632, percent error 29.60

# %%
# Plot the results
fig, ax = plt.subplots()
ax.plot(errors_train,'r-',label='train')
ax.plot(errors_val,'b-',label='test')
ax.set_ylim(0,100); ax.set_xlim(0,n_epoch)
ax.set_xlabel('Epoch'); ax.set_ylabel('Error')
ax.set_title('TrainError %3.2f, Val Error %3.2f'%(errors_train[-1],errors_val[-1]))
ax.legend()
plt.show()

# %% [markdown]
# The primary motivation of residual networks is to allow training of much deeper networks.
#
# TODO: Try running this network with and without the residual connections.  Does adding the residual connections change the performance?
